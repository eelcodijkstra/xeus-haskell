-- %% [markdown]
-- # String formatting

-- %%
import Text.Printf

-- %%
printf "...%d...%s..." 3.4 "hallo"

-- %%
printf "aap"
-- Out:
-- Runtime error: error: "<repl>": line 9, col 3: Cannot satisfy constraint: (PrintfType _a3)
--      fully qualified: (Text.Printf.PrintfType _a3)
