# %% [markdown]
# SVG-test

# %% [markdown]
# ![](example.svg)

# %%
# !ls
# Out:
# example.svg                   nb5.ipynb
# expr.hs                       nb8.ipynb
# introduction_to_haskell.ipynb nb9.ipynb
# nb-test.ipynb                 notatie.ipynb
# nb1.ipynb                     test-svg.ipynb
# nb2.ipynb                     testsvg-example.ipynb
# nb3.ipynb                     testsvg.md
# nb4.ipynb                     Untitled.ipynb
