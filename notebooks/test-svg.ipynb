# %%
from IPython.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
# Out:
# <h1>Hello, world!</h1>

# %%
svgimage = "<g transform=\"translate(50.0 50.0)\" > <circle x=10.0 y=10.0 r=20.0 /><g transform=\"translate(30.0 40.0)\" > <circle x=10.0 y=10.0 r=20.0 /> </g> </g>"

# %%
svgframe = '<svg width="200" height="200" xmlns="http://www.w3.org/2000/svg">' + \
           '<g fill="white" stroke="black" stroke-width="2">' + \
             svgimage + \
           '</g>' + \
           '</svg>'

# %%
mysvg = '''
<svg width="200" height="200" xmlns="http://www.w3.org/2000/svg">
<g transform="translate(40.0 20.0)" stroke="black" fill="white"> 
<circle x=10.0 y=10.0 r=20.0  /> 
<g transform="translate(30.0 40.0)" stroke="blue" stroke-width="3"> 
<circle x=10.0 y=10.0 r=20.0 /> 
</g>
<line x1=10.0 y1=10.0 x2=100.0 y2=100.0  />
</g>'''

# %%
display(HTML(mysvg))
# Out:
# <svg width="200" height="200" xmlns="http://www.w3.org/2000/svg">
# <g transform="translate(40.0 20.0)" stroke="black" fill="white">
# <circle x=10.0 y=10.0 r=20.0  />
# <g transform="translate(30.0 40.0)" stroke="blue" stroke-width="3">
# <circle x=10.0 y=10.0 r=20.0 />
# </g>
# <line x1=10.0 y1=10.0 x2=100.0 y2=100.0  />
#  </g>

# %%
display(HTML(svgframe))
# Out:
# <svg width="200" height="200" xmlns="http://www.w3.org/2000/svg"><g fill="white" stroke="black" stroke-width="2"><g transform="translate(50.0 50.0)" > <circle x=10.0 y=10.0 r=20.0 /><g transform="translate(30.0 40.0)" > <circle x=10.0 y=10.0 r=20.0 /> </g> </g></g></svg>
